# %%
import requests
from bs4 import BeautifulSoup
import os
from urllib.parse import urljoin

# The website you want to scrape
url = "https://pokemondb.net/sprites"  # Change this to your target site

# Folder to save images
os.makedirs("national", exist_ok=True)

# Get the HTML content of the page
headers = {'User-Agent': 'Mozilla/5.0'}
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

# Find all <img> tags
img_tags = soup.find_all("img")

# Download each image
for i, img in enumerate(img_tags):
    img_url = img.get("src")

    # Skip if no src found
    if not img_url:
        continue

    # Convert relative URLs to absolute
    full_url = urljoin(url, img_url)

    # Extract image filename
    filename = os.path.join("national", f"image_{i}.jpg")  # or use os.path.basename(full_url)

    try:
        img_data = requests.get(full_url).content
        with open(filename, "wb") as f:
            f.write(img_data)
        print(f"✅ Saved: {filename}")
    except Exception as e:
        print(f"❌ Failed to download {full_url}: {e}")
# Out:
# ✅ Saved: national\image_0.jpg
# ✅ Saved: national\image_1.jpg
# ✅ Saved: national\image_2.jpg
# ✅ Saved: national\image_3.jpg
# ✅ Saved: national\image_4.jpg
# ✅ Saved: national\image_5.jpg
# ✅ Saved: national\image_6.jpg
# ✅ Saved: national\image_7.jpg
# ✅ Saved: national\image_8.jpg
# ✅ Saved: national\image_9.jpg
# ✅ Saved: national\image_10.jpg
# ✅ Saved: national\image_11.jpg
# ✅ Saved: national\image_12.jpg
# ✅ Saved: national\image_13.jpg
# ✅ Saved: national\image_14.jpg
# ✅ Saved: national\image_15.jpg
# ✅ Saved: national\image_16.jpg
# ✅ Saved: national\image_17.jpg
# ✅ Saved: national\image_18.jpg
# ✅ Saved: national\image_19.jpg
# ✅ Saved: national\image_20.jpg
# ✅ Saved: national\image_21.jpg
# ✅ Saved: national\image_22.jpg
# ✅ Saved: national\image_23.jpg
# ✅ Saved: national\image_24.jpg
# ✅ Saved: national\image_25.jpg
# ✅ Saved: national\image_26.jpg
# ✅ Saved: national\image_27.jpg
# ✅ Saved: national\image_28.jpg
# ✅ Saved: national\image_29.jpg
# ...
